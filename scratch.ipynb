# %%
from bs4 import BeautifulSoup as bs
import pyperclip

# %%
def img(s):
    el = bs(s).find('img')
    src = el.get('src')
    code = f'''<div class="image-container">
    <img src="{src}" style="width: 50%">
</div>'''
    return code.strip()

pyperclip.copy(img('''


<img src="img/Student Peers Biplot.png" width="90%">
</center>
<div style="width: 70%; margin: 0px auto;">




'''))

# %%
html = '''
<div style="width: 80%; margin: 0px auto;">
<center>
<div style="display: flex; justify-content: center;">
    <div>
        <h5>Concentration of Nearest 10 Peers</h5>
        <img src="img/peers-articles.png" width="90%;">
    </div>
    <div>
        <h5>Concentration of Nearest 25 Peers</h5>
        <img src="img/peers-articles25.png" width="90%;">
    </div>
</div>
</center>
</div>
<div style="width: 80%; margin: 0px auto;">
<center>
<div style="display: flex; justify-content: center;">
    <div>
        <h5>Concentration of Nearest 10 Peers</h5>
        <img src="img/peers-citations.png" width="90%;">
    </div>
    <div>
        <h5>Concentration of Nearest 25 Peers</h5>
        <img src="img/peers-citations25.png" width="90%;">
    </div>
</div>
</center>
</div>
<div style="width: 80%; margin: 0px auto;">
<center>
<div style="display: flex; justify-content: center;">
    <div>
        <h5>Concentration of Nearest 10 Peers</h5>
        <img src="img/peers-resdocs.png" width="90%;">
    </div>
    <div>
        <h5>Concentration of Nearest 25 Peers</h5>
        <img src="img/peers-resdocs25.png" width="90%;">
    </div>
</div>
</center>
</div>
<div style="width: 80%; margin: 0px auto;">
<center>
<div style="display: flex; justify-content: center;">
    <div>
        <h5>Concentration of Nearest 10 Peers</h5>
        <img src="img/peers-awards.png" width="90%;">
    </div>
    <div>
        <h5>Concentration of Nearest 25 Peers</h5>
        <img src="img/peers-awards25.png" width="90%;">
    </div>
</div>
</center>
</div>
<div style="width: 80%; margin: 0px auto;">
<center>
<div style="display: flex; justify-content: center;">
    <div>
        <h5>Concentration of Nearest 10 Peers</h5>
        <img src="img/peers-hpawards.png" width="90%;">
    </div>
    <div>
        <h5>Concentration of Nearest 25 Peers</h5>
        <img src="img/peers-hpawards25.png" width="90%;">
    </div>
</div>
</center>
</div>

<div style="width: 80%; margin: 0px auto;">
<center>
<div style="display: flex; justify-content: center;">
    <div>
        <h5>Concentration of Nearest 10 Peers</h5>
        <img src="img/peers-hpawards-excl.png" width="90%;">
    </div>
    <div>
        <h5>Concentration of Nearest 25 Peers</h5>
        <img src="img/peers-hpawards-excl25.png" width="90%;">
    </div>
</div>
</center>
</div>

<div style="width: 80%; margin: 0px auto;">
<center>
<div style="display: flex; justify-content: center;">
    <div>
        <h5>Concentration of Nearest 10 Peers</h5>
        <img src="img/peers-nam.png" width="90%;">
    </div>
    <div>
        <h5>Concentration of Nearest 25 Peers</h5>
        <img src="img/peers-nam25.png" width="90%;">
    </div>
</div>
</center>
</div>

<div style="width: 80%; margin: 0px auto;">
<center>
<div style="display: flex; justify-content: center;">
    <div>
        <h5>Concentration of Nearest 10 Peers</h5>
        <img src="img/peers-phase1.png" width="90%;">
    </div>
    <div>
        <h5>Concentration of Nearest 25 Peers</h5>
        <img src="img/peers-phase1_25.png" width="90%;">
    </div>
</div>
</center>
</div>
<div style="width: 80%; margin: 0px auto;">
<center>
<div style="display: flex; justify-content: center;">
    <div>
        <h5>Concentration of Nearest 10 Peers</h5>
        <img src="img/peers-phase2.png" width="90%;">
    </div>
    <div>
        <h5>Concentration of Nearest 25 Peers</h5>
        <img src="img/peers-phase2_25.png" width="90%;">
    </div>
</div>
</center>
</div>
<div style="width: 80%; margin: 0px auto;">
<center>
<div style="display: flex; justify-content: center;">
    <div>
        <h5>Concentration of Nearest 10 Peers</h5>
        <img src="img/peers-patents-excl.png" width="90%;">
    </div>
    <div>
        <h5>Concentration of Nearest 25 Peers</h5>
        <img src="img/peers-patents-excl25.png" width="90%;">
    </div>
</div>
</center>
</div>
<div style="width: 80%; margin: 0px auto;">
<center>
<div style="display: flex; justify-content: center;">
    <div>
        <h5>Concentration of Nearest 10 Peers</h5>
        <img src="img/peers-clinical.png" width="90%;">
    </div>
    <div>
        <h5>Concentration of Nearest 25 Peers</h5>
        <img src="img/peers-clinical25.png" width="90%;">
    </div>
</div>
</center>
</div>
<div style="width: 80%; margin: 0px auto;">
<center>
<div style="display: flex; justify-content: center;">
    <div>
        <h5>Concentration of Nearest 10 Peers</h5>
        <img src="img/peers-conf.png" width="90%;">
    </div>
    <div>
        <h5>Concentration of Nearest 25 Peers</h5>
        <img src="img/peers-conf25.png" width="90%;">
    </div>
</div>
</center>
</div>
</div>
<div style="width: 70%; margin: 0px auto;">
'''

im = [x.get('src') for x in bs(html).find_all('img')]

im
# Out:
# ['img/peers-articles.png',
#  'img/peers-articles25.png',
#  'img/peers-citations.png',
#  'img/peers-citations25.png',
#  'img/peers-resdocs.png',
#  'img/peers-resdocs25.png',
#  'img/peers-awards.png',
#  'img/peers-awards25.png',
#  'img/peers-hpawards.png',
#  'img/peers-hpawards25.png',
#  'img/peers-hpawards-excl.png',
#  'img/peers-hpawards-excl25.png',
#  'img/peers-nam.png',
#  'img/peers-nam25.png',
#  'img/peers-phase1.png',
#  'img/peers-phase1_25.png',
#  'img/peers-phase2.png',
#  'img/peers-phase2_25.png',
#  'img/peers-patents-excl.png',
#  'img/peers-patents-excl25.png',
#  'img/peers-clinical.png',
#  'img/peers-clinical25.png',
#  'img/peers-conf.png',
#  'img/peers-conf25.png']

# %%
image_sources = [
    'img/peers-articles.png',
    'img/peers-articles25.png',
    'img/peers-citations.png',
    'img/peers-citations25.png',
    'img/peers-resdocs.png',
    'img/peers-resdocs25.png',
    'img/peers-awards.png',
    'img/peers-awards25.png',
    'img/peers-hpawards.png',
    'img/peers-hpawards25.png',
    'img/peers-hpawards-excl.png',
    'img/peers-hpawards-excl25.png',
    'img/peers-nam.png',
    'img/peers-nam25.png',
    'img/peers-phase1.png',
    'img/peers-phase1_25.png',
    'img/peers-phase2.png',
    'img/peers-phase2_25.png',
    'img/peers-patents-excl.png',
    'img/peers-patents-excl25.png',
    'img/peers-clinical.png',
    'img/peers-clinical25.png',
    'img/peers-conf.png',
    'img/peers-conf25.png'
]

# Function to generate HTML for image pairs
def generate_html(image_sources):
    html_output = ""
    for i in range(0, len(image_sources), 2):  # Iterate by steps of 2
        img1 = image_sources[i]
        img2 = image_sources[i+1] if i+1 < len(image_sources) else None
        html_output += f'''
<div class="cols">
    <div>
        <h5 class="caption-subheading">Nearest 10 Peers</h5>
        <img src="{img1}" alt="None" style="max-width:100%; height:auto;">
    </div>'''
        if img2:  # Check if there's a pair
            html_output += f'''
    <div>
        <h5 class="caption-subheading">Nearest 25 Peers</h5>
        <img src="{img2}" alt="None" style="max-width:100%; height:auto;">
    </div>'''
        html_output += "\n</div><br/>\n"
    return html_output

# Generate and print the HTML
html_content = generate_html(image_sources)
pyperclip.copy(html_content)
